# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

arquivo = pd.read_csv('previsao_de_renda.csv')

# %%
df = pd.DataFrame(arquivo)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             15000 non-null  int64
#  1   data_ref               15000 non-null  object
#  2   index                  15000 non-null  int64
#  3   sexo                   15000 non-null  object
#  4   posse_de_veiculo       15000 non-null  bool
#  5   posse_de_imovel        15000 non-null  bool
#  6   qtd_filhos             15000 non-null  int64
#  7   tipo_renda             15000 non-null  object
#  8   educacao               15000 non-null  object
#  9   estado_civil           15000 non-null  object
#  10  tipo_residencia        15000 non-null  object
#  11  idade                  15000 non-null  int64
#  12  tempo_emprego          12466 non-null  float64
#  13  qt_pessoas_residencia  15000 non-null  float64
# ...

# %%
df
# Out:
#        Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0               0  2015-01-01   8682    F             False             True
# 1               1  2015-01-01  12830    M              True             True
# 2               2  2015-01-01   2885    M              True             True
# 3               3  2015-01-01  16168    F              True            False
# 4               4  2015-01-01  12438    M             False            False
# ...           ...         ...    ...  ...               ...              ...
# 14995       14995  2016-03-01   3678    M              True             True
# 14996       14996  2016-03-01   3405    M              True             True
# 14997       14997  2016-03-01   7944    F              True             True
# 14998       14998  2016-03-01  16019    F             False             True
# 14999       14999  2016-03-01  12895    F              True             True
#
# ...

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
ax = sns.countplot(x='data_ref', hue='sexo', data=df)
#tick_labs = df['data_ref'].map(lambda ts: ts.strftime('%m-%Y')).unique()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_27612\486620526.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
ax = sns.countplot(x='data_ref', hue='posse_de_veiculo', data=df)
#tick_labs = df['data_ref'].map(lambda ts: ts.strftime('%m-%Y')).unique()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_27612\2987032682.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
ax = sns.countplot(x='data_ref', hue='posse_de_imovel', data=df)
#tick_labs = df['data_ref'].map(lambda ts: ts.strftime('%m-%Y')).unique()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_27612\445243527.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
ax = sns.countplot(x='data_ref', hue='tipo_renda', data=df)
#tick_labs = df['data_ref'].map(lambda ts: ts.strftime('%m-%Y')).unique()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_27612\233524667.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
ax = sns.countplot(x='data_ref', hue='educacao', data=df)
#tick_labs = df['data_ref'].map(lambda ts: ts.strftime('%m-%Y')).unique()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_27612\2963292614.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
ax = sns.countplot(x='data_ref', hue='estado_civil', data=df)
#tick_labs = df['data_ref'].map(lambda ts: ts.strftime('%m-%Y')).unique()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_27612\2042731941.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
ax = sns.countplot(x='data_ref', hue='tipo_residencia', data=df)
#tick_labs = df['data_ref'].map(lambda ts: ts.strftime('%m-%Y')).unique()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_27612\2956177800.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
ax = sns.countplot(x='data_ref', hue='mau', data=df)
#tick_labs = df['data_ref'].map(lambda ts: ts.strftime('%m-%Y')).unique()
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_27612\2489599339.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %% [markdown]
# Analisando os gráficos acima é possível verificar que aconteceu uma mudança significativa da variável educação ao longo do tempo, onde houve uma redução significativa no valor do secundário e um aumento no valor do superior completo.

# %% [markdown]
# 2) Para cada variável quantitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
ax = sns.pointplot(x='data_ref', y='idade',hue='mau', data= df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_27612\685686893.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
ax = sns.pointplot(x='data_ref', y='qtd_filhos',hue='mau', data= df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_27612\3426523285.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
ax = sns.pointplot(x='data_ref', y='tempo_emprego',hue='mau', data= df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_27612\4147548481.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
ax = sns.pointplot(x='data_ref', y='qt_pessoas_residencia',hue='mau', data= df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_27612\2358159719.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
ax = sns.pointplot(x='data_ref', y='renda',hue='mau', data= df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
print()
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_27612\3524241816.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %% [markdown]
# Verificando os gráficos acima, é possível analisar que houve estabilidade para a categoria de bons pagaderes em todas as situações. Entretanto, no caso dos maus pagadores, houve instabilidade nessa categoria em todos os gráficos. Desta forma, considerando somente a categoria de maus pagadores, as variáveis apresentaram instabilidade e não seria recomendado utilizar elas em uma modelagem para essa categoria.
